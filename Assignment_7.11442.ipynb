# %% [markdown]
# Scipy:
#
#
# We have the min and max temperatures in a city In India for each months of the year.
# We would like to find a function to describe this and show it graphically, the dataset
# given below.
# Task:
# 1. fitting it to the periodic function
# 2. plot the fit
# Data
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %% [markdown]
# <img src="fig1.png">

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %matplotlib inline
months = np.arange(12)

Max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
Min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])


def yearly_temps(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temps, months,
                                      Max, [20, 10, 0])
res_min, cov_min = optimize.curve_fit(yearly_temps, months,
                                      Min, [-40, 20, 0])
days = np.linspace(0, 12, num=365)

plt.figure()
plt.plot(months, Max, 'ro')
plt.plot(days, yearly_temps(days, *res_max), 'r-')
plt.plot(months, Min, 'bo')
plt.plot(days, yearly_temps(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()

# %% [markdown]
# Matplotlib:
#
#
# This assignment is for visualization using matplotlib:
# data to use:
# url=
# https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.cs
# v
# titanic = pd.read_csv(url)
# Charts to plot:
# 1. Create a pie chart presenting the male/female proportion
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv',sep=',')
df.columns = ['pclass','survived','name','sex','age','sibsp','parch','ticket','fare','cabin','embarked','boat','body.home','dest']
male_count = 0
female_count = 0
proportion = []
for i in df.sex:
    if i == 'male':
        male_count = male_count + 1
    else:
        female_count = female_count + 1
print(male_count,female_count)
    
proportion = [male_count,female_count]
labels = ['Males','Females']
fig, ax1 = plt.subplots(figsize = (6,6))
ax1.pie(proportion, explode = (0,0), labels = labels, autopct='%d%%', startangle=90)
ax1.set_title("Sex Proportion")
plt.show()
# Out:
# 843 467

# %% [markdown]
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
plt.scatter(df['age'],df['fare'], alpha=0.5, edgecolor='w',c=pd.factorize(df['sex'])[0])
